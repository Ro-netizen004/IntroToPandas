# %% [markdown]
# <a href="https://colab.research.google.com/github/Ro-netizen004/IntroToPandas/blob/main/Grab_Row_Point_Subset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
my_df = pd.read_csv("dog_data.csv")
my_df
# Out:
#                     Breed              Color        DogName  OwnerZip
# 0                COCKAPOO              BROWN        CHARLEY     15236
# 1            GER SHEPHERD        BLACK/BROWN         TACODA     15238
# 2           BELG MALINOIS            BRINDLE           EICH     15238
# 3                   MIXED        BLACK/BROWN          ARROW     15104
# 4     AM PIT BULL TERRIER        WHITE/BROWN         OAKLEY     15139
# ...                   ...                ...            ...       ...
# 2665         GOLDENDOODLE              BROWN        WINSLOW     15044
# 2666    YORKSHIRE TERRIER        BLACK/BROWN  ROCKY KALAKOS     15220
# 2667              LAB MIX  WHITE/BLACK/BROWN          ELLIE     15220
# 2668         GOLDENDOODLE              WHITE       CLARENCE     15143
# 2669    SHETLAND SHEEPDOG              BLACK        GRIFFIN     15136
#
# [2670 rows x 4 columns]

# %%
# Grab Row Method 1 Location
my_df.loc[0]
# Out:
# Breed       COCKAPOO
# Color          BROWN
# DogName      CHARLEY
# OwnerZip       15236
# Name: 0, dtype: object

# %%
# Grab Row Method 2 Location
my_df.iloc[0]
# Out:
# Breed       COCKAPOO
# Color          BROWN
# DogName      CHARLEY
# OwnerZip       15236
# Name: 0, dtype: object

# %%
# Specific Points (Rows and Columns)
# my_df.loc["Row", "Column"]
my_df.loc[0, "Breed"]
# Out:
# 'COCKAPOO'

# %%
# Subsets
# my_df.loc[['row', 'row'], ['column', 'column']]
my_df.loc[[1,3],["DogName","Breed"]]
# Out:
#   DogName         Breed
# 1  TACODA  GER SHEPHERD
# 3   ARROW         MIXED

# %% [markdown]
# Conditional Selection starts from this point onwards

# %%
# Conditional Selection
my_df == "BROWN"
# Out:
#       Breed  Color  DogName  OwnerZip
# 0     False   True    False     False
# 1     False  False    False     False
# 2     False  False    False     False
# 3     False  False    False     False
# 4     False  False    False     False
# ...     ...    ...      ...       ...
# 2665  False   True    False     False
# 2666  False  False    False     False
# 2667  False  False    False     False
# 2668  False  False    False     False
# 2669  False  False    False     False
#
# [2670 rows x 4 columns]

# %%
# Returns Dataframe with data
my_df[my_df == "BROWN"]
# Out:
#      Breed  Color DogName  OwnerZip
# 0      NaN  BROWN     NaN       NaN
# 1      NaN    NaN     NaN       NaN
# 2      NaN    NaN     NaN       NaN
# 3      NaN    NaN     NaN       NaN
# 4      NaN    NaN     NaN       NaN
# ...    ...    ...     ...       ...
# 2665   NaN  BROWN     NaN       NaN
# 2666   NaN    NaN     NaN       NaN
# 2667   NaN    NaN     NaN       NaN
# 2668   NaN    NaN     NaN       NaN
# 2669   NaN    NaN     NaN       NaN
#
# [2670 rows x 4 columns]

# %%
# Return them on a column
my_df[my_df == "BROWN"]["Color"]
# Out:
# 0       BROWN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#         ...
# 2665    BROWN
# 2666      NaN
# 2667      NaN
# 2668      NaN
# 2669      NaN
# Name: Color, Length: 2670, dtype: object

# %%
my_df[my_df == "BROWN"][["Color", "Breed"]]
# Out:
#       Color Breed
# 0     BROWN   NaN
# 1       NaN   NaN
# 2       NaN   NaN
# 3       NaN   NaN
# 4       NaN   NaN
# ...     ...   ...
# 2665  BROWN   NaN
# 2666    NaN   NaN
# 2667    NaN   NaN
# 2668    NaN   NaN
# 2669    NaN   NaN
#
# [2670 rows x 2 columns]

# %% [markdown]
# Multiple conditionals start from here onwards.

# %%
# Multiple conditionals AND
my_df[(my_df["Color"] == "BROWN") & (my_df["Breed"] == "MIXED")]
# Out:
#       Breed  Color        DogName  OwnerZip
# 42    MIXED  BROWN         STELLA     15044
# 272   MIXED  BROWN           HANK     15220
# 371   MIXED  BROWN          TEDDY     15136
# 402   MIXED  BROWN      GEORGIOUS     15212
# 505   MIXED  BROWN        HERSHEY     15071
# 523   MIXED  BROWN  MINDY MAZUREK     15037
# 572   MIXED  BROWN          STEVE     15229
# 584   MIXED  BROWN           BEAR     15122
# 602   MIXED  BROWN          CHLOE     15106
# 818   MIXED  BROWN         PEANUT     15025
# 943   MIXED  BROWN        DEE DEE     15031
# 946   MIXED  BROWN           SAGE     15035
# 948   MIXED  BROWN          BELLA     15035
# 995   MIXED  BROWN         MISTER     15139
# 1006  MIXED  BROWN        VANESSA     15065
# 1042  MIXED  BROWN           JACK     15223
# 1123  MIXED  BROWN         BUDDIE     15122
# 1195  MIXED  BROWN         COOPER     15071
# 1204  MIXED  BROWN            POE     15044
# 1211  MIXED  BROWN          EPPEY     15218
# ...

# %%
# Return a specific column
my_df[(my_df["Color"] == "BROWN") & (my_df["Breed"] == "MIXED")]["DogName"]
# Out:
# 42             STELLA
# 272              HANK
# 371             TEDDY
# 402         GEORGIOUS
# 505           HERSHEY
# 523     MINDY MAZUREK
# 572             STEVE
# 584              BEAR
# 602             CHLOE
# 818            PEANUT
# 943           DEE DEE
# 946              SAGE
# 948             BELLA
# 995            MISTER
# 1006          VANESSA
# 1042             JACK
# 1123           BUDDIE
# 1195           COOPER
# 1204              POE
# 1211            EPPEY
# 1258             BLUE
# 1322           PHOEBE
# 1466            JAXIE
# 1476            PIPPA
# 1659           ISABEL
# 1780           WILBUR
# 1798             PINO
# 1847           MICKEY
# 2180             KONA
# 2351            BELLA
# 2393           PEANUT
# 2403             TOBY
# 2430             LUCY
# 2441            CASEY
# 2524           PEANUT
# 2562             JEFF
# 2581             BRAX
# 2597           BAILEY
# Name: DogName, dtype: object
